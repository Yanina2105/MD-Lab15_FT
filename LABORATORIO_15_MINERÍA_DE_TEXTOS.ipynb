# %% [markdown]
# <a href="https://colab.research.google.com/github/Yanina2105/MD-Lab15_FT/blob/develop/LABORATORIO_15_MINER%C3%8DA_DE_TEXTOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GLAB15 - MINERÍA DE TEXTOS**

# %%
# pip install chromadb sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 88.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 12.7 MB/s eta 0:00:00
# ...

# %%
import chromadb
from sentence_transformers import SentenceTransformer

# %%
# Inicializar el motor de vectores local
client = chromadb.Client()

# Crear colección (equivalente a una tabla)
collection = client.create_collection(name="alumno")
model = SentenceTransformer('all-MiniLM-L6-v2') # Modelo de embedding

# %%
# Lista de documentos de ejemplo
docs = [
    "Luis es un excelente alumno de ciencia de datos",
    "María tiene interés en la inteligencia artificial",
    "Pedro trabaja en procesamiento de lenguaje natural",
]

# Generar vectores
embeddings = model.encode(docs).tolist()

# Insertar en la colección
collection.add(
    documents=docs,
    embeddings=embeddings,
    ids=["id1", "id2", "id3"]
)

# %%
query = '¿Quién es le gusta procesamiento de lenguaje natural'

query_embedding = model.encode([query]).tolist()

# Buscar los 2 más cercanos
results = collection.query(
    query_embeddings=query_embedding,
    n_results=2
)

print(results['documents'])
# Out:
# [['Pedro trabaja en procesamiento de lenguaje natural', 'Luis es un excelente alumno de ciencia de datos']]

# %%
data = collection.get(include=['embeddings','documents'])

for doc, id_, emb in zip(data['documents'], data['ids'], data['embeddings']):
    print(f"ID: {id_}")
    print(f"Documento: {doc}")
    print(f"Embedding (primeras 5 dimensiones): {emb[:5]}")
    print("-" * 30)
# Out:
# ID: id1
# Documento: Luis es un excelente alumno de ciencia de datos
# Embedding (primeras 5 dimensiones): [-0.0515781   0.07000642 -0.04834177 -0.05982044 -0.01550355]
# ------------------------------
# ID: id2
# Documento: María tiene interés en la inteligencia artificial
# Embedding (primeras 5 dimensiones): [-0.03857211 -0.01005658  0.00841351 -0.03409148 -0.09196933]
# ------------------------------
# ID: id3
# Documento: Pedro trabaja en procesamiento de lenguaje natural
# Embedding (primeras 5 dimensiones): [ 0.04198885  0.0491558  -0.02113147  0.01458174 -0.09477768]
# ------------------------------

# %%
data = collection.get()
print(data)
# Out:
# {'ids': ['id1', 'id2', 'id3'], 'embeddings': None, 'documents': ['Luis es un excelente alumno de ciencia de datos', 'María tiene interés en la inteligencia artificial', 'Pedro trabaja en procesamiento de lenguaje natural'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [None, None, None]}

# %% [markdown]
# # **LABORATORIO 15 - MINERÍA DE TEXTOS**

# %% [markdown]
# ## Cree una base de datos vectorial llamado “Tecsup” y guarde información personal suya y de sus compañeros y luego cree un prompt para poder capturar las respuestas en base a lo guardado.

# %%
# Inicializar el motor de vectores Tecsup
tecsup = chromadb.Client()

# Crear colección (equivalente a una tabla) y diferente motor de embedding
collections = tecsup.create_collection(name="perinfo_alumnos")
model = SentenceTransformer('all-MiniLM-L6-v2') # Modelo de embedding

# %%
# Lista de documentos de ejemplo
doc = [
    "Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica",
    "María es mujer, estudiante de la carrera de redes y le gusta el voley",
    "Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol",
]

# Generar vectores
embeddings = model.encode(doc).tolist()

# Insertar en la colección
collections.add(
    documents=doc,
    embeddings=embeddings,
    ids=["id1", "id2", "id3"]
)

# %%
query = '¿Quienes son mujeres?'

query_embedding = model.encode([query]).tolist()

# Buscar los 2 más cercanos
results = collections.query(
    query_embeddings=query_embedding,
    n_results=2
)

print(results['documents'])
# Out:
# [['María es mujer, estudiante de la carrera de redes y le gusta el voley', 'Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica']]

# %%
data = collections.get(include=['embeddings','documents'])

for doc, id_, emb in zip(data['documents'], data['ids'], data['embeddings']):
    print(f"ID: {id_}")
    print(f"Documento: {doc}")
    print(f"Embedding (primeras 5 dimensiones): {emb[:5]}")
    print("-" * 30)
# Out:
# ID: id1
# Documento: Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica
# Embedding (primeras 5 dimensiones): [ 0.08171076 -0.00874112  0.00623663 -0.03302348 -0.10333832]
# ------------------------------
# ID: id2
# Documento: María es mujer, estudiante de la carrera de redes y le gusta el voley
# Embedding (primeras 5 dimensiones): [ 0.03207373 -0.02929495  0.0749164   0.00971441 -0.04106314]
# ------------------------------
# ID: id3
# Documento: Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol
# Embedding (primeras 5 dimensiones): [ 0.0946264   0.09854972 -0.03020595 -0.06586675  0.00351974]
# ------------------------------

# %%
data = collections.get()
print(data)
# Out:
# {'ids': ['id1', 'id2', 'id3'], 'embeddings': None, 'documents': ['Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica', 'María es mujer, estudiante de la carrera de redes y le gusta el voley', 'Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [None, None, None]}

# %% [markdown]
# ## Luego, utilice la misma solución pero con otro motor de embedding y compare sus respuestas.

# %% [markdown]
# ### **all-mpnet-base-v2**
#
# *   *Performance Sentence Embeddings (14 Datasets):* 69.57
# *   *Performance Semantic Search (6 Datasets):* 57.02
# *   *Avg. Performance:* 63.30
# *   *Speed:* 2800
# *   *Model Size:* 420 MB

# %%
# Inicializar el motor de vectores Tecsup
tecsup = chromadb.Client()

# Crear colección (equivalente a una tabla) y diferente motor de embedding
collections = tecsup.create_collection(name="persona_info_alumnos")
model = SentenceTransformer('all-mpnet-base-v2') # Modelo de embedding
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Lista de documentos de ejemplo
doc = [
    "Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica",
    "María es mujer, estudiante de la carrera de redes y le gusta el voley",
    "Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol",
]

# Generar vectores
embeddings = model.encode(doc).tolist()

# Insertar en la colección
collections.add(
    documents=doc,
    embeddings=embeddings,
    ids=["id1", "id2", "id3"]
)

# %%
query = '¿Que alumnos les gusta los deportes?'

query_embedding = model.encode([query]).tolist()

# Buscar los 2 más cercanos
results = collections.query(
    query_embeddings=query_embedding,
    n_results=2
)

print(results['documents'])
# Out:
# [['María es mujer, estudiante de la carrera de redes y le gusta el voley', 'Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol']]

# %%
data = collections.get(include=['embeddings','documents'])

for doc, id_, emb in zip(data['documents'], data['ids'], data['embeddings']):
    print(f"ID: {id_}")
    print(f"Documento: {doc}")
    print(f"Embedding (primeras 5 dimensiones): {emb[:5]}")
    print("-" * 30)
# Out:
# ID: id1
# Documento: Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica
# Embedding (primeras 5 dimensiones): [-0.01126422  0.03287075 -0.04650551  0.02321     0.01674899]
# ------------------------------
# ID: id2
# Documento: María es mujer, estudiante de la carrera de redes y le gusta el voley
# Embedding (primeras 5 dimensiones): [-0.02640245  0.00482515 -0.01339809  0.00748129  0.00669562]
# ------------------------------
# ID: id3
# Documento: Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol
# Embedding (primeras 5 dimensiones): [-0.01027948 -0.02514851 -0.00797915 -0.0003567  -0.01171392]
# ------------------------------

# %%
data = collections.get()
print(data)
# Out:
# {'ids': ['id1', 'id2', 'id3'], 'embeddings': None, 'documents': ['Fiorella es mujer, estudiante de la carrera de ciencia de datos y le gusta la musica', 'María es mujer, estudiante de la carrera de redes y le gusta el voley', 'Pedro es hombre, estudiante de la carrera de ciencia de datos y le gusta el futbol'], 'uris': None, 'included': ['metadatas', 'documents'], 'data': None, 'metadatas': [None, None, None]}
